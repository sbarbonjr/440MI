# %% [markdown]
# # Python Control Flow and Data Structures
#
# This notebook focuses on two central elements of Python programming:
#
# 1. **Control flow**: deciding which instructions are executed and how often.
# 2. **Data structures**: organizing and manipulating collections of values.
#
# ## Learning objectives
#
# By the end of this notebook, you should be able to use:
#
# - `if`, `elif`, and `else`;
# - logical operators;
# - `for` and `while` loops;
# - `break` and `continue`;
# - lists, tuples, sets, and dictionaries;
# - slicing;
# - list comprehensions;
# - iteration patterns for simple data processing.

# %% [markdown]
# ## 1. Why control flow matters
#
# A program does not always execute every instruction in the same way.
#
# We often want to express logic such as:
#
# - **if** something happens, do one thing;
# - **otherwise**, do something else;
# - **repeat** an operation for several items;
# - **continue** until a condition becomes false.
#
# These mechanisms define the program's control flow.

# %% [markdown]
# ## 2. `if`

# %%
temperature = 38.4

if temperature >= 38:
    print("Fever")

# %% [markdown]
# ## 3. `if` / `else`

# %%
temperature = 37.1

if temperature >= 38:
    print("Fever")
else:
    print("No fever")

# %% [markdown]
# ## 4. `if` / `elif` / `else`

# %%
temperature = 37.7

if temperature >= 39:
    print("High fever")
elif temperature >= 38:
    print("Fever")
elif temperature >= 37.5:
    print("Slightly elevated temperature")
else:
    print("Normal temperature")

# %% [markdown]
# ## 5. Combining conditions

# %%
age = 72
has_diabetes = True

if age >= 65 and has_diabetes:
    print("Both conditions are satisfied")

# %%
temperature = 36.9
has_symptoms = True

if temperature >= 38 or has_symptoms:
    print("Further assessment may be useful")

# %% [markdown]
# ## 6. Nested conditions
#
# You can place an `if` statement inside another one.
#
# However, deeply nested logic can become difficult to read.

# %%
age = 70
temperature = 38.5

if age >= 65:
    if temperature >= 38:
        print("Older patient with fever")

# %% [markdown]
# Often the same logic can be written more clearly:

# %%
if age >= 65 and temperature >= 38:
    print("Older patient with fever")

# %% [markdown]
# # Loops

# %% [markdown]
# ## 7. `for` loops
#
# A `for` loop iterates over the elements of a collection.

# %%
temperatures = [36.5, 37.2, 38.0, 39.1]

for temperature in temperatures:
    print(temperature)

# %%
for temperature in temperatures:
    if temperature >= 38:
        print(f"{temperature} -> fever")
    else:
        print(f"{temperature} -> no fever")

# %% [markdown]
# ## 8. `range()`
#
# `range()` generates a sequence of integers.

# %%
for i in range(5):
    print(i)

# %%
for i in range(2, 6):
    print(i)

# %%
for i in range(0, 10, 2):
    print(i)

# %% [markdown]
# ## 9. `enumerate()`
#
# Use `enumerate()` when you need both an index and a value.

# %%
patients = ["Anna", "Marco", "Elena"]

for index, patient in enumerate(patients):
    print(index, patient)

# %% [markdown]
# ## 10. `zip()`
#
# `zip()` lets us iterate over multiple sequences in parallel.

# %%
patients = ["Anna", "Marco", "Elena"]
temperatures = [36.8, 38.2, 37.1]

for patient, temperature in zip(patients, temperatures):
    print(f"{patient}: {temperature} °C")

# %% [markdown]
# ## 11. `while` loops
#
# A `while` loop continues as long as its condition is true.

# %%
count = 0

while count < 5:
    print(count)
    count += 1

# %% [markdown]
# Be careful with infinite loops: the loop condition must eventually become false.

# %% [markdown]
# ## 12. `break`
#
# `break` stops the loop immediately.

# %%
values = [4, 7, 12, 3, 9]

for value in values:
    if value > 10:
        print("Found:", value)
        break

# %% [markdown]
# ## 13. `continue`
#
# `continue` skips the rest of the current iteration.

# %%
values = [10, -2, 7, -1, 4]

for value in values:
    if value < 0:
        continue

    print(value)

# %% [markdown]
# # Data structures

# %% [markdown]
# ## 14. Lists
#
# Lists are:
#
# - ordered;
# - mutable;
# - able to contain duplicate values.

# %%
temperatures = [36.8, 37.1, 38.2, 36.9]

print(temperatures)
print(type(temperatures))

# %% [markdown]
# ### Indexing

# %%
print(temperatures[0])
print(temperatures[2])
print(temperatures[-1])

# %% [markdown]
# ### Modifying a list

# %%
temperatures = [36.8, 37.1, 38.2]

temperatures.append(39.0)
print(temperatures)

temperatures[0] = 36.6
print(temperatures)

# %%
values = [3, 1, 4]

values.append(2)
print("append:", values)

values.insert(1, 10)
print("insert:", values)

values.remove(4)
print("remove:", values)

last_value = values.pop()
print("pop:", last_value)
print(values)

# %% [markdown]
# ## 15. Slicing
#
# Slicing selects part of a sequence.
#
# ```python
# sequence[start:stop]
# ```
#
# The `stop` index is excluded.

# %%
values = [10, 20, 30, 40, 50, 60]

print(values[1:4])
print(values[:3])
print(values[3:])
print(values[::2])

# %% [markdown]
# ## 16. Tuples
#
# Tuples are ordered but **immutable**.

# %%
coordinates = (45.65, 13.77)

print(coordinates[0])
print(coordinates[1])

# %% [markdown]
# ### Tuple unpacking

# %%
latitude, longitude = coordinates

print(latitude)
print(longitude)

# %% [markdown]
# ## 17. Sets
#
# A `set` contains unique elements.
#
# Sets are useful for:
#
# - removing duplicates;
# - membership tests;
# - set operations.

# %%
departments = {"Cardiology", "Neurology", "Cardiology", "Oncology"}

print(departments)

# %%
group_a = {"A", "B", "C"}
group_b = {"B", "C", "D"}

print("Union:", group_a | group_b)
print("Intersection:", group_a & group_b)
print("Difference:", group_a - group_b)

# %% [markdown]
# ## 18. Dictionaries
#
# Dictionaries store **key-value pairs**.

# %%
patient = {
    "name": "Anna",
    "age": 52,
    "temperature": 37.8,
    "smoker": False
}

print(patient)

# %% [markdown]
# ### Accessing values

# %%
print(patient["name"])
print(patient["temperature"])

# %% [markdown]
# The method `get()` is useful when a key may not exist.

# %%
print(patient.get("blood_pressure"))
print(patient.get("blood_pressure", "Not available"))

# %% [markdown]
# ### Modifying a dictionary

# %%
patient["temperature"] = 38.1
patient["blood_pressure"] = 125

print(patient)

# %% [markdown]
# ### Iterating over dictionaries

# %%
for key in patient:
    print(key)

# %%
for value in patient.values():
    print(value)

# %%
for key, value in patient.items():
    print(key, "->", value)

# %% [markdown]
# ## 19. Nested data structures
#
# A common pattern is a **list of dictionaries**.

# %%
patients = [
    {"name": "Anna", "age": 52, "temperature": 37.8},
    {"name": "Marco", "age": 67, "temperature": 38.4},
    {"name": "Elena", "age": 45, "temperature": 36.9}
]

print(patients[0])
print(patients[0]["name"])

# %%
for patient in patients:
    print(patient["name"], patient["temperature"])

# %% [markdown]
# ## 20. Filtering data with a loop

# %%
patients_with_fever = []

for patient in patients:
    if patient["temperature"] >= 38:
        patients_with_fever.append(patient)

print(patients_with_fever)

# %% [markdown]
# ## 21. List comprehensions
#
# List comprehensions provide a compact way to create lists.
#
# General pattern:
#
# ```python
# new_list = [expression for item in collection]
# ```

# %%
temperatures = [36.5, 37.0, 38.2, 39.1]

temperatures_fahrenheit = [
    temperature * 9 / 5 + 32
    for temperature in temperatures
]

print(temperatures_fahrenheit)

# %% [markdown]
# You can also add a condition.

# %%
fever_temperatures = [
    temperature
    for temperature in temperatures
    if temperature >= 38
]

print(fever_temperatures)

# %% [markdown]
# Use list comprehensions for simple transformations.
#
# If the logic becomes complicated, a regular `for` loop is usually easier to read.

# %% [markdown]
# # Common programming patterns

# %% [markdown]
# ## 22. Accumulator

# %%
temperatures = [36.5, 37.0, 38.2, 39.1]

total = 0

for temperature in temperatures:
    total += temperature

mean_temperature = total / len(temperatures)

print(mean_temperature)

# %% [markdown]
# Python already provides `sum()`:

# %%
mean_temperature = sum(temperatures) / len(temperatures)
print(mean_temperature)

# %% [markdown]
# ## 23. Counter

# %%
number_with_fever = 0

for temperature in temperatures:
    if temperature >= 38:
        number_with_fever += 1

print(number_with_fever)

# %% [markdown]
# ## 24. Search

# %%
target = 38.2
found = False

for temperature in temperatures:
    if temperature == target:
        found = True
        break

print(found)

# %% [markdown]
# The membership operator `in` can often express this more directly:

# %%
print(target in temperatures)

# %% [markdown]
# # Mini case study
#
# We have a small collection of patients.
#
# We want to:
#
# 1. display patient names;
# 2. identify patients with fever;
# 3. compute the mean age;
# 4. build a list containing only the names of patients with fever.

# %%
patients = [
    {"name": "Anna", "age": 52, "temperature": 37.8},
    {"name": "Marco", "age": 67, "temperature": 38.4},
    {"name": "Elena", "age": 45, "temperature": 36.9},
    {"name": "Luca", "age": 73, "temperature": 38.9},
]

for patient in patients:
    print(patient["name"])

# %%
for patient in patients:
    if patient["temperature"] >= 38:
        print(patient["name"], "has fever")

# %%
ages = []

for patient in patients:
    ages.append(patient["age"])

mean_age = sum(ages) / len(ages)

print(mean_age)

# %%
patients_with_fever = [
    patient["name"]
    for patient in patients
    if patient["temperature"] >= 38
]

print(patients_with_fever)

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1 — Conditions
#
# Given:
#
# ```python
# age = 68
# temperature = 38.3
# ```
#
# Print:
#
# - `"High priority"` if `age >= 65` **and** `temperature >= 38`;
# - `"Standard priority"` otherwise.

# %%
age = 68
temperature = 38.3

# Write your solution here

# %% [markdown]
# ## Exercise 2 — Loop and counter
#
# Count how many values are greater than or equal to `10`.

# %%
values = [3, 12, 7, 18, 4, 10]

# Write your solution here

# %% [markdown]
# ## Exercise 3 — List filtering
#
# Create a new list containing only positive values.

# %%
values = [5, -2, 7, -1, 0, 8]

# Write your solution here

# %% [markdown]
# ## Exercise 4 — Dictionary
#
# Create a dictionary describing a patient and print all key-value pairs using a loop.

# %%
# Write your solution here

# %% [markdown]
# ## Exercise 5 — List of dictionaries
#
# Given:

# %%
patients = [
    {"name": "Anna", "age": 52},
    {"name": "Marco", "age": 71},
    {"name": "Elena", "age": 45}
]

# %% [markdown]
# Create a list containing only the names of patients aged 65 or older.

# %%
# Write your solution here

# %% [markdown]
# ## Exercise 6 — List comprehension
#
# Solve Exercise 5 again using a list comprehension.

# %%
# Write your solution here

# %% [markdown]
# # Solutions

# %%
# Exercise 1
age = 68
temperature = 38.3

if age >= 65 and temperature >= 38:
    print("High priority")
else:
    print("Standard priority")

# %%
# Exercise 2
values = [3, 12, 7, 18, 4, 10]

count = 0

for value in values:
    if value >= 10:
        count += 1

print(count)

# %%
# Exercise 3
values = [5, -2, 7, -1, 0, 8]

positive_values = []

for value in values:
    if value > 0:
        positive_values.append(value)

print(positive_values)

# %%
# Exercise 4
patient = {
    "name": "Anna",
    "age": 52,
    "temperature": 37.5
}

for key, value in patient.items():
    print(key, value)

# %%
# Exercise 5
patients = [
    {"name": "Anna", "age": 52},
    {"name": "Marco", "age": 71},
    {"name": "Elena", "age": 45}
]

older_patients = []

for patient in patients:
    if patient["age"] >= 65:
        older_patients.append(patient["name"])

print(older_patients)

# %%
# Exercise 6
older_patients = [
    patient["name"]
    for patient in patients
    if patient["age"] >= 65
]

print(older_patients)

# %% [markdown]
# # Take-home messages
#
# - `if`, `elif`, and `else` control which instructions are executed.
# - `for` is ideal for iterating over collections.
# - `while` is useful when the number of iterations is not known in advance.
# - `break` stops a loop; `continue` skips one iteration.
# - Lists are ordered and mutable.
# - Tuples are ordered and immutable.
# - Sets contain unique elements.
# - Dictionaries map keys to values.
# - A list of dictionaries is a simple way to represent structured records.
# - List comprehensions are useful for concise, readable transformations.
